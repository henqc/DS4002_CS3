# %% [markdown]
# <a href="https://colab.research.google.com/github/abkerper/DS4002_Project2/blob/main/Draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/abkerper/DS4002_Project2
# Out:
# fatal: destination path 'DS4002_Project2' already exists and is not an empty directory.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
df1 = pd.read_csv('/content/SA_0000001400.csv')
df2 = pd.read_csv('/content/SA_0000001688.csv')

# %%
df = pd.concat([df1,df2])

# %%
display(df.columns)
# Out:
# Index(['Id', 'IndicatorCode', 'SpatialDimension', 'SpatialDimensionValueCode',
#        'ParentLocationCode', 'ParentLocation', 'TimeDimension', 'TimeDim',
#        'DisaggregatingDimension1', 'DisaggregatingDimension1ValueCode',
#        'DisaggregatingDimension2', 'DisaggregatingDimension2ValueCode',
#        'DisaggregatingDimension3', 'DisaggregatingDimension3ValueCode',
#        'DataSourceDimension', 'DataSourceDimensionValueCode', 'Value',
#        'NumericValue', 'Low', 'High', 'Comments', 'Date', 'TimeDimensionValue',
#        'TimeDimensionBegin', 'TimeDimensionEnd'],
#       dtype='object')

# %%
display(df)
# Out:
#             Id  IndicatorCode SpatialDimension SpatialDimensionValueCode  \
# 0          114  SA_0000001400          COUNTRY                       LBY
# 1          363  SA_0000001400          COUNTRY                       ARE
# 2          533  SA_0000001400          COUNTRY                       NGA
# 3          541  SA_0000001400          COUNTRY                       PNG
# 4          786  SA_0000001400          COUNTRY                       USA
# ...        ...            ...              ...                       ...
# 12835  7672875  SA_0000001688          COUNTRY                       COG
# 12836  7672984  SA_0000001688          COUNTRY                       THA
# 12837  7673464  SA_0000001688          COUNTRY                       ISL
# 12838  7673716  SA_0000001688          COUNTRY                       DNK
# 12839  7674087  SA_0000001688          COUNTRY                       QAT
#
#       ParentLocationCode         ParentLocation TimeDimension  TimeDim  \
# 0                    EMR  Eastern Mediterranean          YEAR     2015
# 1                    EMR  Eastern Mediterranean          YEAR     2014
# 2                    AFR                 Africa          YEAR     1969
# 3                    WPR        Western Pacific          YEAR     1973
# 4                    AMR               Americas          YEAR     1981
# ...                  ...                    ...           ...      ...
# 12835                AFR                 Africa          YEAR     2008
# 12836               SEAR        South-East Asia          YEAR     2018
# 12837                EUR                 Europe          YEAR     2018
# 12838                EUR                 Europe          YEAR     2019
# 12839                EMR  Eastern Mediterranean          YEAR     2008
#
#       DisaggregatingDimension1 DisaggregatingDimension1ValueCode  ...  \
# 0                  ALCOHOLTYPE      ALCOHOLTYPE_SA_OTHER_ALCOHOL  ...
# 1                  ALCOHOLTYPE      ALCOHOLTYPE_SA_OTHER_ALCOHOL  ...
# 2                  ALCOHOLTYPE               ALCOHOLTYPE_SA_WINE  ...
# 3                  ALCOHOLTYPE            ALCOHOLTYPE_SA_SPIRITS  ...
# 4                  ALCOHOLTYPE               ALCOHOLTYPE_SA_BEER  ...
# ...                        ...                               ...  ...
# 12835                      SEX                          SEX_FMLE  ...
# 12836                      SEX                          SEX_FMLE  ...
# 12837                      SEX                           SEX_MLE  ...
# 12838                      SEX                          SEX_FMLE  ...
# 12839                      SEX                           SEX_MLE  ...
#
#        DataSourceDimensionValueCode              Value  NumericValue      Low  \
# 0               DATASOURCE_GISAHLBY                0.0       0.00447      NaN
# 1               DATASOURCE_GISAHARE                0.0       0.01357      NaN
# 2               DATASOURCE_GISAHNGA                0.0       0.00000      NaN
# 3               DATASOURCE_GISAHPNG               0.21       0.21000      NaN
# 4               DATASOURCE_GISAHUSA               5.26       5.26000      NaN
# ...                             ...                ...           ...      ...
# 12835                           NaN    1.7 [0.9 - 2.5]       1.67733  0.86551
# 12836                           NaN    3.0 [2.0 - 4.1]       3.04399  2.02587
# 12837                           NaN  12.3 [8.6 - 16.2]      12.28169  8.61431
# 12838                           NaN    4.3 [3.0 - 5.8]       4.28697  2.95253
# 12839                           NaN    1.5 [0.3 - 2.7]       1.45897  0.33259
#
#            High Comments                  Date  TimeDimensionValue  \
# 0           NaN      NaN  2024-08-12T15:16:09Z                2015
# 1           NaN      NaN  2024-08-12T15:16:09Z                2014
# 2           NaN      NaN  2018-05-11T09:09:10Z                1969
# 3           NaN      NaN  2018-05-11T09:04:40Z                1973
# 4           NaN      NaN  2018-05-11T09:09:54Z                1981
# ...         ...      ...                   ...                 ...
# 12835   2.51619      NaN  2024-06-21T08:49:58Z                2008
# 12836   4.14774      NaN  2024-06-21T08:49:58Z                2018
# 12837  16.19484      NaN  2024-06-21T08:49:58Z                2018
# 12838   5.78829      NaN  2024-06-21T08:49:58Z                2019
# 12839   2.71296      NaN  2024-06-21T08:49:58Z                2008
#
#        TimeDimensionBegin  TimeDimensionEnd
# 0              2015-01-01        2015-12-31
# 1              2014-01-01        2014-12-31
# 2              1969-01-01        1969-12-31
# 3              1973-01-01        1973-12-31
# 4              1981-01-01        1981-12-31
# ...                   ...               ...
# 12835          2008-01-01        2008-12-31
# 12836          2018-01-01        2018-12-31
# 12837          2018-01-01        2018-12-31
# 12838          2019-01-01        2019-12-31
# 12839          2008-01-01        2008-12-31
#
# [61764 rows x 25 columns]

# %%
display(df.columns)
# Out:
# Index(['Id', 'IndicatorCode', 'SpatialDimension', 'SpatialDimensionValueCode',
#        'ParentLocationCode', 'ParentLocation', 'TimeDimension', 'TimeDim',
#        'DisaggregatingDimension1', 'DisaggregatingDimension1ValueCode',
#        'DisaggregatingDimension2', 'DisaggregatingDimension2ValueCode',
#        'DisaggregatingDimension3', 'DisaggregatingDimension3ValueCode',
#        'DataSourceDimension', 'DataSourceDimensionValueCode', 'Value',
#        'NumericValue', 'Low', 'High', 'Comments', 'Date', 'TimeDimensionValue',
#        'TimeDimensionBegin', 'TimeDimensionEnd'],
#       dtype='object')

# %%
df.drop(columns=['ParentLocationCode',
                 'ParentLocation',
                 'TimeDimension',
                 'DisaggregatingDimension2',
                 'DisaggregatingDimension2ValueCode',
                 'DisaggregatingDimension3',
                 'DisaggregatingDimension3ValueCode',
                 'DataSourceDimension',
                 'DataSourceDimensionValueCode'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-745a5c9c8937> in <cell line: 1>()
# ----> 1 df.drop(columns=['ParentLocationCode',
#       2                  'ParentLocation',
#       3                  'TimeDimension',
#       4                  'DisaggregatingDimension2',
#       5                  'DisaggregatingDimension2ValueCode',
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['ParentLocationCode', 'ParentLocation', 'TimeDimension', 'DisaggregatingDimension2', 'DisaggregatingDimension2ValueCode', 'DisaggregatingDimension3', 'DisaggregatingDimension3ValueCode', 'DataSourceDimension', 'DataSourceDimensionValueCode'] not found in axis"

# %%
df = df[df['SpatialDimension']=='COUNTRY']

# %%
display(df['SpatialDimension'].unique())
# Out:
# array(['COUNTRY', 'UNREGION', 'GLOBAL', 'REGION'], dtype=object)

# %%
df.drop(columns=['IndicatorName', 'IndicatorCode'], inplace=True)
